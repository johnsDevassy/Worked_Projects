# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
sum=0
finaldict={}
def findit(xM,ar,k,sum=0,sett=[]):
  sum=sum+ar[k]
  sett.append(ar[k])
  print(sum,"1st")
  if sum>xM:
    k=k-1
    
    sum=sum-ar[k+1]
    print(sum,"sum1st","k",k)
    kys=finaldict.keys()
    print(finaldict,"finaldict")
    if sum not in kys:
      print(sum,"sum",sett,"set")
      finaldict.__setitem__(sum, sett)
    print(sett,"sett1")
    print(finaldict,"afterdictins")
    sett.pop(len(sett)-1)

    if k!=-1:
      print(sum,'sum2nd')
      
      findit(xM,ar,k,sum,sett)
  elif sum==xM:
    kys=finaldict.keys()
    print(finaldict," finaal dict in eauals")
    if sum not in kys:
      finaldict.__setitem__(sum, sett)
    exit
  else:      
    print(ar[k],"going")
    k=k-1
    if(sum < xM and k !=-1):
      print(sum,"sum in else")
      print(sett)
      findit(xM,ar,k,sum,sett)
      k=k-1
      if k !=-1:
        sett.pop(len(sett)-1)
        findit(xM,ar,k,sum,sett)

# %%
x=22

noftypes=5
piecesinorder=[3,3,5,6,10]
print(findit(x,piecesinorder,4))
print(finaldict)
# Out:
# 10 1st
# 10 going
# 10 sum in else
# [10]
# 16 1st
# 6 going
# 16 sum in else
# [10, 6]
# 21 1st
# 5 going
# 21 sum in else
# [10, 6, 5]
# 24 1st
# 21 sum1st k 0
# {} finaldict
# 21 sum [10, 6, 5, 3] set
# [10, 6, 5, 3] sett1
# {21: [10, 6, 5, 3]} afterdictins
# 21 sum2nd
# 24 1st
# 21 sum1st k -1
# {21: [10, 6, 5, 3]} finaldict
# [10, 6, 5, 3] sett1
# {21: [10, 6, 5, 3]} afterdictins
# 24 1st
# 21 sum1st k -1
# {21: [10, 6, 3]} finaldict
# [10, 6, 3] sett1
# {21: [10, 6, 3]} afterdictins
# 19 1st
# 3 going
# 19 sum in else
# [10, 3]
# 22 1st
# {21: [10, 3, 3]}  finaal dict in eauals
# 15 1st
# 5 going
# 15 sum in else
# [10, 3, 5]
# 18 1st
# 3 going
# 18 sum in else
# [10, 3, 5, 3]
# 21 1st
# 3 going
# 18 1st
# 3 going
# None
# {21: [10, 3, 5, 3, 3], 22: [10, 3, 5, 3, 3]}

# %%
dicta = {1:[4,3]} 
s=dicta.keys()
if 1  in s:
  print("hai")
# Out:
# hai
